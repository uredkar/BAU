# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

from numpy.lib.stride_tricks import as_strided
import matplotlib.pyplot as plt
import pandas_datareader as web
import yfinance as yf

def download(file_name,symbols):
   

    yf_data = yf.download(symbols,  start = "2005-02-01" , end = "2022-12-01")
    newcolnames = [col[0] + col[1] for col in yf_data.columns.values]
    yf_data
    yf_data.columns = newcolnames
    yf_data.reset_index(inplace=True)
    yf_data.columns
    yf_data.to_csv(file_name, index=False)

# %%
file_name = 'vanguard.csv'
# use SPY instead of VOO since spy has more price history
symbols = ['VTV','VB', 'VTI', 'SPY','VUG','VXUS','VGK','VDE','VWO','VBK','VTIP','BND','BNDX']
download(file_name,symbols)
# Out:
# [*********************100%***********************]  13 of 13 completed

# %%
df_vanguard = pd.read_csv("vanguard.csv")
df_vanguard.head(2)
# Out:
#          Date  Adj CloseBND  Adj CloseBNDX  Adj CloseSPY  Adj CloseVB  \
# 0  2005-02-01           NaN            NaN     84.298782    42.236012
# 1  2005-02-02           NaN            NaN     84.553978    42.445549
#
#    Adj CloseVBK  Adj CloseVDE  Adj CloseVGK  Adj CloseVTI  Adj CloseVTIP  ...  \
# 0     46.481964     37.072823           NaN     41.463337            NaN  ...
# 1     46.765667     37.670547           NaN     41.653214            NaN  ...
#
#    VolumeVB  VolumeVBK  VolumeVDE  VolumeVGK  VolumeVTI  VolumeVTIP  \
# 0   1845100       5500      19400        NaN     174800         NaN
# 1      3300     134000      31700        NaN     167000         NaN
#
#    VolumeVTV  VolumeVUG  VolumeVWO  VolumeVXUS
# 0      19600      10600        NaN         NaN
# 1      62900       8400        NaN         NaN
#
# [2 rows x 79 columns]

# %%
vanguard_adj_close = ["Adj Close" + symbol for symbol in symbols]
df_vanguard[vanguard_adj_close]
# Out:
#       Adj CloseVTV  Adj CloseVB  Adj CloseVTI  Adj CloseSPY  Adj CloseVUG  \
# 0        33.786419    42.236012     41.463337     84.298782     40.937851
# 1        33.948635    42.445549     41.653214     84.553978     41.118088
# 2        33.911190    42.305851     41.445419     84.334198     40.921455
# 3        34.185722    42.926746     41.964851     85.234573     41.183609
# 4        34.285564    42.864651     41.946941     85.121124     41.355659
# ...            ...          ...           ...           ...           ...
# 4485    144.690002   193.490005    201.389999    402.420013    229.759995
# 4486    145.089996   194.580002    201.539993    402.329987    228.929993
# 4487    143.110001   190.470001    198.270004    395.910004    224.929993
# 4488    143.559998   191.199997    197.960007    395.230011    223.169998
# 4489    146.240005   196.089996    204.059998    407.679993    233.039993
#
#       Adj CloseVXUS  Adj CloseVGK  Adj CloseVDE  Adj CloseVWO  Adj CloseVBK  \
# 0               NaN           NaN     37.072823           NaN     46.481964
# 1               NaN           NaN     37.670547           NaN     46.765667
# 2               NaN           NaN     37.804867           NaN     46.561752
# 3               NaN           NaN     38.013065           NaN     47.067101
# 4               NaN           NaN     37.690697           NaN     47.262123
# ...             ...           ...           ...           ...           ...
# 4485      52.500000     56.099998    128.970001     38.919998    211.089996
# 4486      52.619999     56.480000    128.759995     38.779999    211.330002
# 4487      52.029999     55.570000    125.120003     38.689999    207.179993
# 4488      52.439999     55.700001    126.800003     39.450001    207.270004
# 4489      53.500000     56.790001    127.629997     40.520000    214.529999
#
#       Adj CloseVTIP  Adj CloseBND  Adj CloseBNDX
# 0               NaN           NaN            NaN
# 1               NaN           NaN            NaN
# 2               NaN           NaN            NaN
# 3               NaN           NaN            NaN
# 4               NaN           NaN            NaN
# ...             ...           ...            ...
# 4485      47.720001     72.395454      48.950047
# 4486      47.689999     72.395454      48.900108
# 4487      47.700001     72.305656      48.720329
# 4488      47.639999     72.036270      48.860157
# 4489      48.000000     72.595001      48.989998
#
# [4490 rows x 13 columns]

# %%
df_vanguard[vanguard_adj_close].plot()
# Out:
# <AxesSubplot:>

# %%
def stock_data(prices,col):
    df = pd.DataFrame({'Date':prices.Date, 'Values':prices[col]})

    x = df['Date'].tolist()
    y = df['Values'].tolist()

    plt.style.use('dark_background')
    plt.plot(x,y)
    plt.ylabel('Price($)')
    plt.xlabel('Date', rotation=0)
    plt.show()
stock_data(df_vanguard,"Adj CloseBND")

# %%
def plot_hist_returns(title,price_data,period,w):
    """
    price_data df with price data index by date
    w weight of each symbol fixed weight for ex ante hist
    """
    
    print(sum(w))
    ret_data = price_data.pct_change(periods=period)[1:]
    #print(ret_data.head())
    weighted_returns = (w * ret_data)
    #print(weighted_returns.head())
    port_ret = weighted_returns.sum(axis=1)

    fig = plt.figure()
    ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
    ax1.hist(port_ret, bins = 60)
    ax1.set_xlabel('Portfolio returns')
    ax1.set_ylabel("Freq")
    ax1.set_title(title)
    plt.show();

# %%
prices = df_vanguard[vanguard_adj_close]
wt = [1 / len(prices.columns)] * len(prices.columns)
plot_hist_returns("Hist of Daily Portfolio Returns",prices,1,wt)
# Out:
# 0.9999999999999998

# %%
plot_hist_returns("Hist of Daily Portfolio Returns",prices,7,wt)
# Out:
# 0.9999999999999998

# %%
plot_hist_returns("Hist of Daily Portfolio Returns",prices,30,wt)
# Out:
# 0.9999999999999998

# %%
plot_hist_returns("Hist of Daily Portfolio Returns",prices,90,wt)
# Out:
# 0.9999999999999998

# %%
prices.rolling(100, win_type='gaussian').mean(std=3).plot()
# Out:
# <AxesSubplot:>

# %%
# Out:
# Date
# 2022-06-06 00:00:00-04:00    116.327499
# 2022-06-13 00:00:00-04:00    106.786499
# 2022-06-20 00:00:00-04:00    108.929497
# 2022-06-27 00:00:00-04:00    118.273003
# 2022-07-04 00:00:00-04:00    107.100502
# 2022-07-11 00:00:00-04:00    117.998001
# 2022-07-18 00:00:00-04:00    112.639999
# 2022-07-25 00:00:00-04:00    108.410004
# 2022-08-01 00:00:00-04:00    115.300003
# 2022-08-08 00:00:00-04:00    118.389999
# 2022-08-15 00:00:00-04:00    121.129997
# 2022-08-22 00:00:00-04:00    115.199997
# 2022-08-29 00:00:00-04:00    109.989998
# 2022-09-05 00:00:00-04:00    107.300003
# 2022-09-12 00:00:00-04:00    110.989998
# 2022-09-19 00:00:00-04:00    101.750000
# 2022-09-26 00:00:00-04:00     98.099998
# 2022-10-03 00:00:00-04:00     96.760002
# 2022-10-10 00:00:00-04:00     99.000000
# 2022-10-17 00:00:00-04:00     98.860001
# 2022-10-24 00:00:00-04:00    101.800003
# 2022-10-31 00:00:00-04:00     95.419998
# 2022-11-07 00:00:00-05:00     87.279999
# 2022-11-14 00:00:00-05:00     95.089996
# 2022-11-21 00:00:00-05:00     97.290001
# 2022-11-28 00:00:00-05:00     97.040001
# 2022-12-05 00:00:00-05:00     99.400002
# 2022-12-09 00:00:00-05:00     93.769997
# Name: Open, dtype: float64

# %% [markdown]
# def download_prices(symbols,filename):
#     df = web.get_data_yahoo(symbols,
#                                    start = '2017-06-01',
#                                    end = '2021-10-01')
#     df = df['Adj Close']
#     print(df.head())
#     df.to_csv(filename, index=True)
#
# symbols = ['VOO','VEA', 'VB', 'VWO','BND']
# download_prices(symbols,"vanguard.csv")

# %% [markdown]
# symbols = ['FDFIX','FLXSX','FLAPX','FITFX','FIBUX','BND','SHV']
# download_prices(symbols,"fidelity.csv")

# %%
# Out:
#                Adj Close         Adj Close.1         Adj Close.2  \
# 0                    BND                BNDX                  VB
# 1     55.575748443603516                 NaN  46.906700134277344
# 2      55.61082077026367                 NaN   47.54866409301758
# 3     55.575748443603516                 NaN   47.20684051513672
# 4     55.680904388427734                 NaN   45.58936309814453
# ...                  ...                 ...                 ...
# 3228   72.39545440673828   48.95004653930664  193.49000549316406
# 3229   72.39545440673828  48.900108337402344   194.5800018310547
# 3230   72.30565643310547   48.72032928466797  190.47000122070312
# 3231   72.03627014160156   48.86015701293945   191.1999969482422
# 3232   72.59500122070312   48.98999786376953  196.08999633789062
#
#              Adj Close.3         Adj Close.4         Adj Close.5  \
# 0                    VBK                 VDE                 VGK
# 1      53.42110824584961    58.6539192199707   29.70037078857422
# 2     54.068572998046875   59.60282897949219  30.159440994262695
# 3      53.85881423950195  59.032039642333984  29.783245086669922
# 4      51.79785919189453   56.54920196533203   28.32309341430664
# ...                  ...                 ...                 ...
# 3228  211.08999633789062  128.97000122070312  56.099998474121094
# 3229   211.3300018310547  128.75999450683594   56.47999954223633
# 3230  207.17999267578125  125.12000274658203   55.56999969482422
# 3231  207.27000427246094  126.80000305175781   55.70000076293945
# 3232  214.52999877929688  127.62999725341797  56.790000915527344
#
#              Adj Close.6         Adj Close.7         Adj Close.8  \
# 0                    VOO                 VTI                 VTV
# 1                    NaN   43.58269119262695   34.01137924194336
# 2                    NaN   44.14337158203125  34.544612884521484
# 3                    NaN   43.92225646972656   34.27078628540039
# 4                    NaN   42.55609893798828   33.18270492553711
# ...                  ...                 ...                 ...
# 3228   369.8399963378906  201.38999938964844  144.69000244140625
# 3229  369.79998779296875   201.5399932861328  145.08999633789062
# 3230  363.95001220703125  198.27000427246094  143.11000061035156
# 3231  363.30999755859375   197.9600067138672  143.55999755859375
# 3232    374.489990234375  204.05999755859375  146.24000549316406
#
#              Adj Close.9  ... Volume.2 Volume.3 Volume.4 Volume.5   Volume.6  \
# 0                    VUG  ...       VB      VBK      VDE      VGK        VOO
# 1     44.415199279785156  ...   200400   139400   168600   500000        NaN
# 2      44.86445999145508  ...   150900    96300   222100   460400        NaN
# 3      44.80399703979492  ...  3936900    81200   159900   577200        NaN
# 4      43.38710403442383  ...   296800   204400   213200   993100        NaN
# ...                  ...  ...      ...      ...      ...      ...        ...
# 3228  229.75999450683594  ...   423500   163300   433200  4139500  2590900.0
# 3229  228.92999267578125  ...   384300   125700   278700  1452500  1423400.0
# 3230  224.92999267578125  ...   534900   226900   650300  5008800  3553600.0
# 3231   223.1699981689453  ...   453000   301300   403500  2967000  2507800.0
# 3232   233.0399932861328  ...   789600   391500   596700  6660100  4748800.0
#
#      Volume.7 Volume.8 Volume.9 Volume.10  Volume.11
# 0         VTI      VTV      VUG       VWO       VXUS
# 1     2132800   291400   539700  10503100        NaN
# 2     2565500   306900   358000  19955200        NaN
# 3     1352600   387100   281400  12056000        NaN
# 4     3029700   534600   661300  16197300        NaN
# ...       ...      ...      ...       ...        ...
# 3228  2685700  2159500   900900   8148200  3692000.0
# 3229  1289100  1201100   483400   4877400  1578000.0
# 3230  3365800  2293200  1175600  14967900  4598400.0
# 3231  2640700  1962700  1107400  12193700  2997000.0
# 3232  4198100  3095300  1686600  16331300  4961800.0
#
# [3233 rows x 72 columns]

# %%
# Out:
#    index          Adj Close        Adj Close.1         Adj Close.2  \
# 0      0                BND               BNDX                  VB
# 1      1  83.74847412109375  55.58666229248047  198.34963989257812
# 2      2  83.64297485351562  55.53890609741211    201.087646484375
# 3      3  83.49910736083984   55.4720344543457   201.6450653076172
#
#          Adj Close.3        Adj Close.4         Adj Close.5  \
# 0                VBK                VDE                 VGK
# 1  277.8032531738281  51.09825134277344   57.08344650268555
# 2  283.2957458496094  51.65568542480469    57.6875114440918
# 3   283.057373046875  53.82039260864258  57.744136810302734
#
#           Adj Close.6         Adj Close.7         Adj Close.8  ... Volume.2  \
# 0                 VOO                 VTI                 VTV  ...       VB
# 1   337.0036315917969   192.5337677001953  114.05303192138672  ...   611100
# 2   341.8476257324219  195.29542541503906  115.51142883300781  ...   697100
# 3  342.18878173828125  195.58815002441406   115.9527816772461  ...   614700
#
#   Volume.3 Volume.4 Volume.5 Volume.6 Volume.7 Volume.8 Volume.9 Volume.10  \
# 0      VBK      VDE      VGK      VOO      VTI      VTV      VUG       VWO
# 1   221100   897300  3100000  3334000  3900700  2516200   793000  14517800
# 2   231000   827800  3366200  2955200  3278700  1930200   737300   8347500
# 3   191400  1074700  4393600  3392800  2905600  1849100   685300   8442500
#
#   Volume.11
# 0      VXUS
# 1   3365000
# 2   3736100
# 3   3723300
#
# [4 rows x 73 columns]

# %%
# Out:
#            Adj Close        Adj Close.1         Adj Close.2  \
# 0                BND               BNDX                  VB
# 1  83.74847412109375  55.58666229248047  198.34963989257812
# 2  83.64297485351562  55.53890609741211    201.087646484375
# 3  83.49910736083984   55.4720344543457   201.6450653076172
#
#          Adj Close.3        Adj Close.4         Adj Close.5  \
# 0                VBK                VDE                 VGK
# 1  277.8032531738281  51.09825134277344   57.08344650268555
# 2  283.2957458496094  51.65568542480469    57.6875114440918
# 3   283.057373046875  53.82039260864258  57.744136810302734
#
#           Adj Close.6         Adj Close.7         Adj Close.8  \
# 0                 VOO                 VTI                 VTV
# 1   337.0036315917969   192.5337677001953  114.05303192138672
# 2   341.8476257324219  195.29542541503906  115.51142883300781
# 3  342.18878173828125  195.58815002441406   115.9527816772461
#
#           Adj Close.9  ... Volume.2 Volume.3 Volume.4 Volume.5 Volume.6  \
# 0                 VUG  ...       VB      VBK      VDE      VGK      VOO
# 1  254.29510498046875  ...   611100   221100   897300  3100000  3334000
# 2  258.84051513671875  ...   697100   231000   827800  3366200  2955200
# 3   258.1968994140625  ...   614700   191400  1074700  4393600  3392800
#
#   Volume.7 Volume.8 Volume.9 Volume.10 Volume.11
# 0      VTI      VTV      VUG       VWO      VXUS
# 1  3900700  2516200   793000  14517800   3365000
# 2  3278700  1930200   737300   8347500   3736100
# 3  2905600  1849100   685300   8442500   3723300
#
# [4 rows x 72 columns]
#            Adj Close        Adj Close.1         Adj Close.2  \
# 0                BND               BNDX                  VB
# 1  83.74847412109375  55.58666229248047  198.34963989257812
# 2  83.64297485351562  55.53890609741211    201.087646484375
# 3  83.49910736083984   55.4720344543457   201.6450653076172
#
#          Adj Close.3        Adj Close.4         Adj Close.5  \
# 0                VBK                VDE                 VGK
# 1  277.8032531738281  51.09825134277344   57.08344650268555
# 2  283.2957458496094  51.65568542480469    57.6875114440918
# 3   283.057373046875  53.82039260864258  57.744136810302734
#
#           Adj Close.6         Adj Close.7         Adj Close.8  \
# 0                 VOO                 VTI                 VTV
# 1   337.0036315917969   192.5337677001953  114.05303192138672
# 2   341.8476257324219  195.29542541503906  115.51142883300781
# 3  342.18878173828125  195.58815002441406   115.9527816772461
#
#           Adj Close.9  ... Volume.2 Volume.3 Volume.4 Volume.5 Volume.6  \
# 0                 VUG  ...       VB      VBK      VDE      VGK      VOO
# 1  254.29510498046875  ...   611100   221100   897300  3100000  3334000
# 2  258.84051513671875  ...   697100   231000   827800  3366200  2955200
# 3   258.1968994140625  ...   614700   191400  1074700  4393600  3392800
#
#   Volume.7 Volume.8 Volume.9 Volume.10 Volume.11
# 0      VTI      VTV      VUG       VWO      VXUS
# 1  3900700  2516200   793000  14517800   3365000
# 2  3278700  1930200   737300   8347500   3736100
# 3  2905600  1849100   685300   8442500   3723300
#
# [4 rows x 72 columns]

# %%
# axis =1 tells pandas we want to add
# the rows
