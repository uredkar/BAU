# %%
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web
"""
VOO SP500
VEA DEVELOPED MARKET
VB SMALL CAP
VWO EMERGING MARKET
BND TOTAL BOND MARKET
TAIL TAIL RISK
VXF SMALL MID CAP (except SP500)
VXUS TOTAL INTERNATION
FDFIX SP 500 41.16
FLXSX SMALL CAP 3.92
FLAPX MID CAP 3.92
FITFX INTERNATIONL 21
FIBUX BOND INDEX 25.00
FJTDX CONSERVATIVE 4.50
FLGXX MONEY MARKET .50


symbols = ['VOO','VEA', 'VB', 'VWO','BND']


symbols = ['FDFIX','FLXSX','FLAPX','FITFX','FIBUX','FJTDX','FLGXX']
price_data = web.get_data_yahoo(symbols,
                               start = '2017-06-01',
                               end = '2021-10-01')

price_data.to_csv('fidelity.csv', index=False) 


symbols = ['SHV']
price_data = web.get_data_yahoo(symbols,
                               start = '2017-06-01',
                               end = '2021-10-01')

price_data.to_csv('SHV.csv', index=False) 
"""

# %%
def download_prices(symbols,filename):
    df = web.get_data_yahoo(symbols,
                                   start = '2017-06-01',
                                   end = '2021-10-01')
    df = df['Adj Close']
    print(df.head())
    df.to_csv(filename, index=True) 
    
symbols = ['VOO','VEA', 'VB', 'VWO','BND']
download_prices(symbols,"vanguard.csv")
# Out:
# Symbols            VOO        VEA          VB        VWO        BND
# Date
# 2017-06-01  205.743652  36.792721  126.842537  36.362495  72.847275
# 2017-06-02  206.388336  37.144638  127.312233  36.477684  73.087692
# 2017-06-05  206.250183  36.986279  126.711014  36.477684  72.971901
# 2017-06-06  205.660797  36.898293  126.353996  36.504272  73.105469
# 2017-06-07  206.001556  36.871902  126.260063  36.477684  73.007561

# %%
symbols = ['FDFIX','FLXSX','FLAPX','FITFX','FIBUX','BND','SHV']
download_prices(symbols,"fidelity.csv")
# Out:
# Symbols        FDFIX     FLXSX     FLAPX      FITFX     FIBUX        BND  \
# Date
# 2017-06-01  9.610501  9.583435  9.661138  10.000485  9.157722  72.847244
# 2017-06-02  9.638412  9.648631  9.670420  10.092234  9.184608  73.087708
# 2017-06-05  9.629107  9.592751  9.642577  10.073883  9.166682  72.971939
# 2017-06-06  9.601199  9.583435  9.605454  10.055532  9.184608  73.105507
# 2017-06-07  9.619805  9.592751  9.605454  10.037184  9.175649  73.007553
#
# Symbols            SHV
# Date
# 2017-06-01  104.779053
# 2017-06-02  104.798073
# 2017-06-05  104.788574
# 2017-06-06  104.779053
# 2017-06-07  104.788574

# %%
def load_prices(filename):
    df = pd.read_csv(filename)  
    print(df.head())
    return df
df_fidelity = load_prices("fidelity.csv")
print(df_fidelity.tail())
df_vanguard = load_prices("vanguard.csv")
print(df_vanguard.tail())
# Out:
#          Date     FDFIX     FLXSX     FLAPX      FITFX     FIBUX        BND  \
# 0  2017-06-01  9.610501  9.583435  9.661138  10.000485  9.157722  72.847244
# 1  2017-06-02  9.638412  9.648631  9.670420  10.092234  9.184608  73.087708
# 2  2017-06-05  9.629107  9.592751  9.642577  10.073883  9.166682  72.971939
# 3  2017-06-06  9.601199  9.583435  9.605454  10.055532  9.184608  73.105507
# 4  2017-06-07  9.619805  9.592751  9.605454  10.037184  9.175649  73.007553
#
#           SHV
# 0  104.779053
# 1  104.798073
# 2  104.788574
# 3  104.779053
# 4  104.788574
#             Date      FDFIX      FLXSX      FLAPX  FITFX  FIBUX        BND  \
# 1088  2021-09-27  19.020000  16.610001  17.510000  14.01  10.61  85.699425
# 1089  2021-09-28  18.629999  16.240000  17.180000  13.73  10.57  85.329987
# 1090  2021-09-29  18.660000  16.209999  17.180000  13.70  10.57  85.339973
# 1091  2021-09-30  18.440001  16.059999  16.980000  13.68  10.58  85.320000
# 1092  2021-10-01  18.590000  16.330000  17.190001  13.71  10.61  85.610001
#
#              SHV
# 1088  110.459999
# 1089  110.459999
# 1090  110.459999
# 1091  110.470001
# 1092  110.459999
#          Date         VOO        VEA          VB        VWO        BND
# 0  2017-06-01  205.743652  36.792721  126.842537  36.362495  72.847275
# 1  2017-06-02  206.388336  37.144638  127.312233  36.477684  73.087692
# 2  2017-06-05  206.250183  36.986279  126.711014  36.477684  72.971901
# 3  2017-06-06  205.660797  36.898293  126.353996  36.504272  73.105469
# 4  2017-06-07  206.001556  36.871902  126.260063  36.477684  73.007561
#             Date         VOO        VEA          VB        VWO        BND
# 1088  2021-09-27  406.965332  51.950001  226.259995  50.660000  85.699425
# 1089  2021-09-28  398.832031  50.799999  222.029999  50.070000  85.329987
# 1090  2021-09-29  399.459991  50.639999  221.839996  49.669998  85.339973
# 1091  2021-09-30  394.399994  50.490002  218.669998  50.009998  85.320000
# 1092  2021-10-01  399.119995  50.639999  222.080002  50.040001  85.610001

# %%
def display_analysis(price_data,w):
    price_data['Date'] = pd.to_datetime(price_data['Date'])
    price_data = price_data.set_index('Date')
    price_data.head()
    
    print(sum(w))
    ret_data = price_data.pct_change()[1:]
    print(ret_data.head())
    weighted_returns = (w * ret_data)
    print(weighted_returns.head())
    port_ret = weighted_returns.sum(axis=1)

    fig = plt.figure()
    ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
    ax1.hist(port_ret, bins = 60)
    ax1.set_xlabel('Portfolio returns')
    ax1.set_ylabel("Freq")
    ax1.set_title("Portfolio Returns calculated manually")
    plt.show(); 
    pf.create_returns_tear_sheet(port_ret)

# %%
w = [0.40,0.04,0.04,0.21,0.25,0.05,0.01]
display_analysis(df_fidelity,w)
# Out:
# 1.0
#                FDFIX     FLXSX     FLAPX     FITFX     FIBUX       BND  \
# Date
# 2017-06-02  0.002904  0.006803  0.000961  0.009174  0.002936  0.003301
# 2017-06-05 -0.000965 -0.005792 -0.002879 -0.001818 -0.001952 -0.001584
# 2017-06-06 -0.002898 -0.000971 -0.003850 -0.001822  0.001955  0.001830
# 2017-06-07  0.001938  0.000972  0.000000 -0.001825 -0.000975 -0.001340
# 2017-06-08  0.000000  0.013592  0.002899  0.000000 -0.000977 -0.000732
#
#                  SHV
# Date
# 2017-06-02  0.000182
# 2017-06-05 -0.000091
# 2017-06-06 -0.000091
# 2017-06-07  0.000091
# 2017-06-08  0.000000
#                FDFIX     FLXSX     FLAPX     FITFX     FIBUX       BND  \
# Date
# 2017-06-02  0.001162  0.000272  0.000038  0.001927  0.000734  0.000165
# 2017-06-05 -0.000386 -0.000232 -0.000115 -0.000382 -0.000488 -0.000079
# 2017-06-06 -0.001159 -0.000039 -0.000154 -0.000383  0.000489  0.000092
# 2017-06-07  0.000775  0.000039  0.000000 -0.000383 -0.000244 -0.000067
# 2017-06-08  0.000000  0.000544  0.000116  0.000000 -0.000244 -0.000037
#
#                      SHV
# Date
# 2017-06-02  1.815256e-06
# 2017-06-05 -9.063713e-07
# 2017-06-06 -9.086376e-07
# 2017-06-07  9.087202e-07
# 2017-06-08  0.000000e+00
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-06-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>52</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>10.764%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>55.738%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.1%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.43</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.83</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.942%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.15</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.20</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>22.33</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.606%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.94</td>
#       <td>2020-02-19</td>
#       <td>2020-03-23</td>
#       <td>2020-07-29</td>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>12.86</td>
#       <td>2018-01-26</td>
#       <td>2018-12-24</td>
#       <td>2019-04-01</td>
#       <td>307</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.60</td>
#       <td>2020-09-02</td>
#       <td>2020-09-23</td>
#       <td>2020-11-09</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.85</td>
#       <td>2019-05-03</td>
#       <td>2019-05-31</td>
#       <td>2019-06-19</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.79</td>
#       <td>2019-07-24</td>
#       <td>2019-08-14</td>
#       <td>2019-09-11</td>
#       <td>36</td>
#     </tr>
#   </tbody>
# </table>

# %%
w = [0.40,0.20,0.10,0.10,20]
display_analysis(df_vanguard,w)
# Out:
# 20.8
#                  VOO       VEA        VB       VWO       BND
# Date
# 2017-06-02  0.003133  0.009565  0.003703  0.003168  0.003300
# 2017-06-05 -0.000669 -0.004263 -0.004722  0.000000 -0.001584
# 2017-06-06 -0.002858 -0.002379 -0.002818  0.000729  0.001830
# 2017-06-07  0.001657 -0.000715 -0.000743 -0.000728 -0.001339
# 2017-06-08  0.000358 -0.001432  0.009226  0.001943 -0.000732
#                  VOO       VEA        VB       VWO       BND
# Date
# 2017-06-02  0.001253  0.001913  0.000370  0.000317  0.066006
# 2017-06-05 -0.000268 -0.000853 -0.000472  0.000000 -0.031686
# 2017-06-06 -0.001143 -0.000476 -0.000282  0.000073  0.036608
# 2017-06-07  0.000663 -0.000143 -0.000074 -0.000073 -0.026785
# 2017-06-08  0.000143 -0.000286  0.000923  0.000194 -0.014639
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-06-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>52</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>nan%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-535.913%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>106.842%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.83</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-140.857%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-3.12</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>120.51</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.07</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-13.11%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>140.86</td>
#       <td>2020-03-06</td>
#       <td>2020-08-06</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>51.51</td>
#       <td>2017-09-07</td>
#       <td>2018-05-17</td>
#       <td>2019-01-31</td>
#       <td>366</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>35.44</td>
#       <td>2019-09-04</td>
#       <td>2019-09-13</td>
#       <td>2020-01-15</td>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16.67</td>
#       <td>2019-07-03</td>
#       <td>2019-07-11</td>
#       <td>2019-08-01</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.76</td>
#       <td>2017-06-26</td>
#       <td>2017-07-07</td>
#       <td>2017-07-20</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>

# %%
# axis =1 tells pandas we want to add
# the rows
